# %% [markdown]
# <a href="https://colab.research.google.com/github/subhendue-kd/NBICT-LAB-PDSML-B-6-Subhendue-Kumar-Debnath-SL-66/blob/main/2.%20Random%20Forest%20Regression/Random_Forest_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing the dataset

# %%
dataset = pd.read_csv("Drug_Effectiveness.csv")
X = dataset.iloc[ : , 0:-1].values
y = dataset.iloc[ : , -1].values

# %% [markdown]
# # Random Forest Regression

# %% [markdown]
# ## Training the Random Forest regression model

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=100,random_state=0)
regressor.fit(X,y)
# Out:
# RandomForestRegressor(random_state=0)

# %% [markdown]
# ## Predicting a New Result

# %%
print(regressor.predict([[12]]))
# Out:
# [25.13]

# %% [markdown]
# ## Visualizing the Random Forest  Regresson model

# %%
plt.scatter(X, y, color="red")
plt.plot(X, regressor.predict(X), color="blue")
plt.title("Dosage VS Effectiveness")
plt.xlabel("Dosages (mg)")
plt.ylabel("Effectiveness (%)")
plt.show()
